# %% [markdown]
# 1. Setup

# %%
lukmanhadoop@LAPTOP-2O9TRIF8:~$ cd ~/mapreduceheart
lukmanhadoop@LAPTOP-2O9TRIF8:~/mapreduceheart$ ls
mapper.py  mapper_avg.py  reducer.py  reducer_avg  reducer_avg.py  results  run.sh
lukmanhadoop@LAPTOP-2O9TRIF8:~/mapreduceheart$ export JAVA_HOME=/usr/lib/jvm/java-8-openjdk-amd64
lukmanhadoop@LAPTOP-2O9TRIF8:~/mapreduceheart$ export HADOOP_HOME=~/hadoop
lukmanhadoop@LAPTOP-2O9TRIF8:~/mapreduceheart$ export PATH=$PATH:$HADOOP_HOME/bin:$HADOOP_HOME/sbin

# %% [markdown]
# 2. Start DFS & Yarn

# %%
lukmanhadoop@LAPTOP-2O9TRIF8:~/mapreduceheart$ start-dfs.sh
Starting namenodes on [localhost]
Starting datanodes
Starting secondary namenodes [LAPTOP-2O9TRIF8]
lukmanhadoop@LAPTOP-2O9TRIF8:~/mapreduceheart$ start-yarn.sh
Starting resourcemanager
Starting nodemanagers
lukmanhadoop@LAPTOP-2O9TRIF8:~/mapreduceheart$ jps
23251 NameNode
23817 ResourceManager
23595 SecondaryNameNode
24318 Jps
23934 NodeManager
23375 DataNode

# %% [markdown]
# 3. Upload Dataset

# %%
lukmanhadoop@LAPTOP-2O9TRIF8:~/mapreduceheart$ cp "/mnt/d/Lukman S2/Semester 2/IT PLATFORM AND INFRASTRUCTURE/Tugas/RTM 2/heart.csv" ~/
lukmanhadoop@LAPTOP-2O9TRIF8:~/mapreduceheart$ ls ~
hadoop               heart.csv  mapper_avg.py   reducer.py      spark
hadoop-3.3.6.tar.gz  mapper.py  mapreduceheart  reducer_avg.py  spark-3.5.1-bin-hadoop3.tgz
lukmanhadoop@LAPTOP-2O9TRIF8:~/mapreduceheart$ hdfs dfs -rm -r -f /input
lukmanhadoop@LAPTOP-2O9TRIF8:~/mapreduceheart$ hdfs dfs -mkdir -p /input
lukmanhadoop@LAPTOP-2O9TRIF8:~/mapreduceheart$ hdfs dfs -put ~/heart.csv /input/
lukmanhadoop@LAPTOP-2O9TRIF8:~/mapreduceheart$ hdfs dfs -ls /input
Found 1 items
-rw-r--r--   1 lukmanhadoop supergroup      38114 2026-05-04 19:02 /input/heart.csv

# %% [markdown]
# 4. Run MapReduce

# %%
lukmanhadoop@LAPTOP-2O9TRIF8:~/mapreduceheart$ ./run.sh
Running COUNT...
packageJobJar: [/tmp/hadoop-unjar8530296772365332335/] [] /tmp/streamjob2526267764414801668.jar tmpDir=null
2026-05-04 19:03:37,132 INFO client.DefaultNoHARMFailoverProxyProvider: Connecting to ResourceManager at /0.0.0.0:8032
2026-05-04 19:03:37,372 INFO client.DefaultNoHARMFailoverProxyProvider: Connecting to ResourceManager at /0.0.0.0:8032
2026-05-04 19:03:37,773 INFO mapreduce.JobResourceUploader: Disabling Erasure Coding for path: /tmp/hadoop-yarn/staging/lukmanhadoop/.staging/job_1777896024169_0001
2026-05-04 19:03:39,132 INFO mapred.FileInputFormat: Total input files to process : 1
2026-05-04 19:03:40,088 INFO mapreduce.JobSubmitter: number of splits:2
2026-05-04 19:03:40,671 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_1777896024169_0001
2026-05-04 19:03:40,671 INFO mapreduce.JobSubmitter: Executing with tokens: []
2026-05-04 19:03:40,958 INFO conf.Configuration: resource-types.xml not found
2026-05-04 19:03:40,959 INFO resource.ResourceUtils: Unable to find 'resource-types.xml'.
2026-05-04 19:03:42,089 INFO impl.YarnClientImpl: Submitted application application_1777896024169_0001
2026-05-04 19:03:42,156 INFO mapreduce.Job: The url to track the job: http://LAPTOP-2O9TRIF8.localdomain:8088/proxy/application_1777896024169_0001/
2026-05-04 19:03:42,159 INFO mapreduce.Job: Running job: job_1777896024169_0001
2026-05-04 19:03:52,353 INFO mapreduce.Job: Job job_1777896024169_0001 running in uber mode : false
2026-05-04 19:03:52,356 INFO mapreduce.Job:  map 0% reduce 0%
2026-05-04 19:03:58,477 INFO mapreduce.Job:  map 100% reduce 0%
2026-05-04 19:04:04,994 INFO mapreduce.Job:  map 100% reduce 100%
2026-05-04 19:04:07,038 INFO mapreduce.Job: Job job_1777896024169_0001 completed successfully
2026-05-04 19:04:07,159 INFO mapreduce.Job: Counters: 54
        File System Counters
                FILE: Number of bytes read=6156
                FILE: Number of bytes written=852233
                FILE: Number of read operations=0
                FILE: Number of large read operations=0
                FILE: Number of write operations=0
                HDFS: Number of bytes read=42388
                HDFS: Number of bytes written=12
                HDFS: Number of read operations=11
                HDFS: Number of large read operations=0
                HDFS: Number of write operations=2
                HDFS: Number of bytes read erasure-coded=0
        Job Counters
                Launched map tasks=2
                Launched reduce tasks=1
                Data-local map tasks=2
                Total time spent by all maps in occupied slots (ms)=7501
                Total time spent by all reduces in occupied slots (ms)=3599
                Total time spent by all map tasks (ms)=7501
                Total time spent by all reduce tasks (ms)=3599
                Total vcore-milliseconds taken by all map tasks=7501
                Total vcore-milliseconds taken by all reduce tasks=3599
                Total megabyte-milliseconds taken by all map tasks=7681024
                Total megabyte-milliseconds taken by all reduce tasks=3685376
        Map-Reduce Framework
                Map input records=1026
                Map output records=1025
                Map output bytes=4100
                Map output materialized bytes=6162
                Input split bytes=178
                Combine input records=0
                Combine output records=0
                Reduce input groups=2
                Reduce shuffle bytes=6162
                Reduce input records=1025
                Reduce output records=2
                Spilled Records=2050
                Shuffled Maps =2
                Failed Shuffles=0
                Merged Map outputs=2
                GC time elapsed (ms)=572
                CPU time spent (ms)=4720
                Physical memory (bytes) snapshot=1006366720
                Virtual memory (bytes) snapshot=7696912384
                Total committed heap usage (bytes)=976224256
                Peak Map Physical memory (bytes)=494133248
                Peak Map Virtual memory (bytes)=2563444736
                Peak Reduce Physical memory (bytes)=229699584
                Peak Reduce Virtual memory (bytes)=2570248192
        Shuffle Errors
                BAD_ID=0
                CONNECTION=0
                IO_ERROR=0
                WRONG_LENGTH=0
                WRONG_MAP=0
                WRONG_REDUCE=0
        File Input Format Counters
                Bytes Read=42210
        File Output Format Counters
                Bytes Written=12
2026-05-04 19:04:07,159 INFO streaming.StreamJob: Output directory: /output/count

real    0m32.549s
user    0m9.833s
sys     0m1.255s
Running AVG...
packageJobJar: [/tmp/hadoop-unjar7831463436984414906/] [] /tmp/streamjob2843687206959291724.jar tmpDir=null
2026-05-04 19:04:15,665 INFO client.DefaultNoHARMFailoverProxyProvider: Connecting to ResourceManager at /0.0.0.0:8032
2026-05-04 19:04:15,910 INFO client.DefaultNoHARMFailoverProxyProvider: Connecting to ResourceManager at /0.0.0.0:8032
2026-05-04 19:04:16,380 INFO mapreduce.JobResourceUploader: Disabling Erasure Coding for path: /tmp/hadoop-yarn/staging/lukmanhadoop/.staging/job_1777896024169_0002
2026-05-04 19:04:17,707 INFO mapred.FileInputFormat: Total input files to process : 1
2026-05-04 19:04:17,824 INFO mapreduce.JobSubmitter: number of splits:2
2026-05-04 19:04:17,993 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_1777896024169_0002
2026-05-04 19:04:17,993 INFO mapreduce.JobSubmitter: Executing with tokens: []
2026-05-04 19:04:18,253 INFO conf.Configuration: resource-types.xml not found
2026-05-04 19:04:18,254 INFO resource.ResourceUtils: Unable to find 'resource-types.xml'.
2026-05-04 19:04:18,367 INFO impl.YarnClientImpl: Submitted application application_1777896024169_0002
2026-05-04 19:04:18,454 INFO mapreduce.Job: The url to track the job: http://LAPTOP-2O9TRIF8.localdomain:8088/proxy/application_1777896024169_0002/
2026-05-04 19:04:18,458 INFO mapreduce.Job: Running job: job_1777896024169_0002
2026-05-04 19:04:26,650 INFO mapreduce.Job: Job job_1777896024169_0002 running in uber mode : false
2026-05-04 19:04:26,652 INFO mapreduce.Job:  map 0% reduce 0%
2026-05-04 19:04:33,900 INFO mapreduce.Job:  map 100% reduce 0%
2026-05-04 19:04:42,458 INFO mapreduce.Job:  map 100% reduce 100%
2026-05-04 19:04:42,483 INFO mapreduce.Job: Job job_1777896024169_0002 completed successfully
2026-05-04 19:04:42,628 INFO mapreduce.Job: Counters: 54
        File System Counters
                FILE: Number of bytes read=11281
                FILE: Number of bytes written=862573
                FILE: Number of read operations=0
                FILE: Number of large read operations=0
                FILE: Number of write operations=0
                HDFS: Number of bytes read=42388
                HDFS: Number of bytes written=41
                HDFS: Number of read operations=11
                HDFS: Number of large read operations=0
                HDFS: Number of write operations=2
                HDFS: Number of bytes read erasure-coded=0
        Job Counters
                Launched map tasks=2
                Launched reduce tasks=1
                Data-local map tasks=2
                Total time spent by all maps in occupied slots (ms)=8315
                Total time spent by all reduces in occupied slots (ms)=5902
                Total time spent by all map tasks (ms)=8315
                Total time spent by all reduce tasks (ms)=5902
                Total vcore-milliseconds taken by all map tasks=8315
                Total vcore-milliseconds taken by all reduce tasks=5902
                Total megabyte-milliseconds taken by all map tasks=8514560
                Total megabyte-milliseconds taken by all reduce tasks=6043648
        Map-Reduce Framework
                Map input records=1026
                Map output records=1025
                Map output bytes=9225
                Map output materialized bytes=11287
                Input split bytes=178
                Combine input records=0
                Combine output records=0
                Reduce input groups=2
                Reduce shuffle bytes=11287
                Reduce input records=1025
                Reduce output records=2
                Spilled Records=2050
                Shuffled Maps =2
                Failed Shuffles=0
                Merged Map outputs=2
                GC time elapsed (ms)=1268
                CPU time spent (ms)=7220
                Physical memory (bytes) snapshot=1220710400
                Virtual memory (bytes) snapshot=7699959808
                Total committed heap usage (bytes)=1272971264
                Peak Map Physical memory (bytes)=495841280
                Peak Map Virtual memory (bytes)=2563653632
                Peak Reduce Physical memory (bytes)=230203392
                Peak Reduce Virtual memory (bytes)=2573713408
        Shuffle Errors
                BAD_ID=0
                CONNECTION=0
                IO_ERROR=0
                WRONG_LENGTH=0
                WRONG_MAP=0
                WRONG_REDUCE=0
        File Input Format Counters
                Bytes Read=42210
        File Output Format Counters
                Bytes Written=41
2026-05-04 19:04:42,628 INFO streaming.StreamJob: Output directory: /output/avg

real    0m29.530s
user    0m9.807s
sys     0m1.113s
lukmanhadoop@LAPTOP-2O9TRIF8:~/mapreduceheart$ cp -r ~/mapreduceheart/results /mnt/d/Lukman\ S2/Semester\ 2/IT\ PLATFORM\ AND\ INFRASTRUCTURE/Tugas/RTM\ 2/mapreduceheart/
lukmanhadoop@LAPTOP-2O9TRIF8:~/mapreduceheart$ cat results/count.txt
0       499
1       526
lukmanhadoop@LAPTOP-2O9TRIF8:~/mapreduceheart$ cat results/avg.txt
0       56.569138276553105
1       52.40874524714829
